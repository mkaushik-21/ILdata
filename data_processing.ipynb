# %% [markdown]
# <a href="https://colab.research.google.com/github/mkaushik-21/ILdata/blob/master/data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install xlrd
# !pip install psycopg2

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import psycopg2 as ps
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# Insert excel file into google colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-228041db-605c-41d0-9c18-4be482a74a57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-228041db-605c-41d0-9c18-4be482a74a57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IL solubilities database.xlsx to IL solubilities database.xlsx

# %% [markdown]
# Read the excel file as df, now the spreadsheet can be used

# %%
import io
df= pd.read_excel(io.BytesIO(uploaded['IL solubilities database.xlsx']))
df
# Out:
#                  IL  cation   anion  ...  [DEPO4]  [DBPO4]  [methide]
# 0       [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# 1       [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# 2       [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# 3       [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# 4       [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# ...             ...     ...     ...  ...      ...      ...        ...
# 10113  [HMIM][Tf2N]  [HMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 10114  [HMIM][Tf2N]  [HMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 10115  [HMIM][Tf2N]  [HMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 10116           NaN     NaN     NaN  ...     57.0     18.0       21.0
# 10117           NaN     NaN     NaN  ...      NaN      NaN        NaN
#
# [10118 rows x 57 columns]

# %%
df.head()
# Out:
#             IL  cation  anion  x_CO2  ...  [DMPO4]  [DEPO4]  [DBPO4]  [methide]
# 0  [BMIM][BF4]  [BMIM]  [BF4]   0.61  ...      0.0      0.0      0.0        0.0
# 1  [BMIM][BF4]  [BMIM]  [BF4]   0.50  ...      0.0      0.0      0.0        0.0
# 2  [BMIM][BF4]  [BMIM]  [BF4]   0.61  ...      0.0      0.0      0.0        0.0
# 3  [BMIM][BF4]  [BMIM]  [BF4]   0.50  ...      0.0      0.0      0.0        0.0
# 4  [BMIM][BF4]  [BMIM]  [BF4]   0.61  ...      0.0      0.0      0.0        0.0
#
# [5 rows x 57 columns]

# %%
df.columns
# Out:
# Index(['IL', 'cation', 'anion', 'x_CO2', 'T (K)', 'P (bar)', '[CH3]', '[CH2]',
#        '[CH]', '[OCH2]', '[OCH3]', '[CF2]', '[CF3]', '[OH]', 'CH=CH', 'CH=CH2',
#        '[Im13]', '[MIm]', '[MMIM]', '[Py]', '[MPy]', '[MPyrro]', '[MPip]',
#        '[NH3]', '[NH2]', '[NH]', '[N]', '[P]', '[S]', '[BF4]', '[Cl]', '[DCA]',
#        '[NO3]', '[PF6]', '[SCN]', '[TCB]', '[C(CN)3]', '[HSO4]', '[FSA]',
#        '[Tf2N]', '[BETA]', '[FOR]', '[TFA]', '[C3F7CO2]', '[MeSO4]', '[EtSO4]',
#        '[MDEGSO4]', '[MeSO3]', '[TfO]', '[NfO]', '[TDfO]', '[TOS]',
#        '[C12PhSO3]', '[DMPO4]', '[DEPO4]', '[DBPO4]', '[methide]'],
#       dtype='object')

# %% [markdown]
# Use shape to learn how many rows and columns

# %%
df.shape
# Out:
# (10118, 57)

# %%
df.dtypes
# Out:
# IL             object
# cation         object
# anion          object
# x_CO2         float64
# T (K)         float64
# P (bar)       float64
# [CH3]         float64
# [CH2]         float64
# [CH]          float64
# [OCH2]        float64
# [OCH3]        float64
# [CF2]         float64
# [CF3]         float64
# [OH]          float64
# CH=CH         float64
# CH=CH2        float64
# [Im13]        float64
# [MIm]         float64
# [MMIM]        float64
# [Py]          float64
# [MPy]         float64
# [MPyrro]      float64
# [MPip]        float64
# [NH3]         float64
# [NH2]         float64
# [NH]          float64
# [N]           float64
# [P]           float64
# [S]           float64
# [BF4]         float64
# [Cl]          float64
# [DCA]         float64
# [NO3]         float64
# [PF6]         float64
# [SCN]         float64
# [TCB]         float64
# [C(CN)3]      float64
# [HSO4]        float64
# [FSA]         float64
# [Tf2N]        float64
# [BETA]        float64
# ...

# %% [markdown]
# Create another dataset, cation, that groups the df by cations and counts how many IL's used with each cation. This allows us to determine which cation was used the most.

# %%
cation= df.groupby('cation').count()
cation.sort_values('IL', ascending=False)
# Out:
#                  IL  anion  x_CO2  T (K)  ...  [DMPO4]  [DEPO4]  [DBPO4]  [methide]
# cation                                    ...
# [BMIM]         2902   2902   2902   2902  ...     2902     2902     2902       2902
# [HMIM]         1467   1467   1467   1467  ...     1467     1467     1467       1467
# [EMIM]         1449   1449   1449   1449  ...     1449     1449     1449       1449
# [OMIM]          735    735    735    735  ...      735      735      735        735
# [P6,6,6,14]     445    445    445    445  ...      445      445      445        445
# [BMPYR]         265    265    265    265  ...      265      265      265        265
# [C3OMIM]        229    229    229    229  ...      229      229      229        229
# [HOC2MIM]       177    177    177    177  ...      177      177      177        177
# [C5MPYR]        160    160    160    160  ...      160      160      160        160
# [C5MIM]         139    139    139    139  ...      139      139      139        139
# ...

# %%
cation.shape
# Out:
# (56, 56)

# %% [markdown]
# Use .nunique to determine how many unique IL's, cations, and anions were used

# %%
df.nunique()
# Out:
# IL             124
# cation          56
# anion           28
# x_CO2         3655
# T (K)         1279
# P (bar)       4946
# [CH3]            7
# [CH2]           17
# [CH]             3
# [OCH2]           4
# [OCH3]           3
# [CF2]            4
# [CF3]            3
# [OH]             5
# CH=CH            3
# CH=CH2           3
# [Im13]           4
# [MIm]            3
# [MMIM]           3
# [Py]             3
# [MPy]            3
# [MPyrro]         3
# [MPip]           3
# [NH3]            3
# [NH2]            3
# [NH]             3
# [N]              3
# [P]              3
# [S]              3
# [BF4]            3
# [Cl]             3
# [DCA]            3
# [NO3]            3
# [PF6]            3
# [SCN]            3
# [TCB]            3
# [C(CN)3]         3
# [HSO4]           3
# [FSA]            3
# [Tf2N]           3
# [BETA]           3
# [FOR]            3
# [TFA]            3
# [C3F7CO2]        3
# [MeSO4]          3
# [EtSO4]          3
# [MDEGSO4]        3
# ...

# %% [markdown]
# Do same process as cations for anions, to determine the most common anion used.

# %%
anion= df.groupby('anion').count()
anion
# Out:
#               IL  cation  x_CO2  T (K)  ...  [DMPO4]  [DEPO4]  [DBPO4]  [methide]
# anion                                   ...
# [BETA]        11      11     11     11  ...       11       11       11         11
# [BF4]       1116    1116   1116   1116  ...     1116     1116     1116       1116
# [C(CN)3]     755     755    755    755  ...      755      755      755        755
# [C12PhSO3]   112     112    112    112  ...      112      112      112        112
# [C3F7CO2]     28      28     28     28  ...       28       28       28         28
# [Cl]         156     156    156    156  ...      156      156      156        156
# [DBPO4]       18      18     18     18  ...       18       18       18         18
# [DCA]        220     220    220    220  ...      220      220      220        220
# [DEPO4]       57      57     57     57  ...       57       57       57         57
# [DMPO4]       12      12     12     12  ...       12       12       12         12
# ...

# %%
anion.sort_values('IL', ascending=False)
# Out:
#               IL  cation  x_CO2  T (K)  ...  [DMPO4]  [DEPO4]  [DBPO4]  [methide]
# anion                                   ...
# [Tf2N]      4301    4301   4301   4301  ...     4301     4301     4301       4301
# [PF6]       1116    1116   1116   1116  ...     1116     1116     1116       1116
# [BF4]       1116    1116   1116   1116  ...     1116     1116     1116       1116
# [C(CN)3]     755     755    755    755  ...      755      755      755        755
# [TfO]        555     555    555    555  ...      555      555      555        555
# [MeSO3]      230     230    230    230  ...      230      230      230        230
# [DCA]        220     220    220    220  ...      220      220      220        220
# [SCN]        208     208    208    208  ...      208      208      208        208
# [MeSO4]      178     178    178    178  ...      178      178      178        178
# [NO3]        160     160    160    160  ...      160      160      160        160
# ...

# %%
anion.shape
# Out:
# (28, 56)

# %%
anion.shape
# Out:
# (28, 56)

# %% [markdown]
# Use .describe() to determine different values about the dataset

# %%
df.describe()
# Out:
#               x_CO2         T (K)  ...       [DBPO4]     [methide]
# count  1.011800e+04  10118.000000  ...  10117.000000  10117.000000
# mean   7.136643e+07    325.790455  ...      0.003558      0.004151
# std    5.075804e+09     45.084951  ...      0.183835      0.213666
# min    6.480000e-05    243.200000  ...      0.000000      0.000000
# 25%    1.350000e-01    308.150000  ...      0.000000      0.000000
# 50%    2.992000e-01    323.150000  ...      0.000000      0.000000
# 75%    5.120000e-01    342.640000  ...      0.000000      0.000000
# max    3.610428e+11   2982.000000  ...     18.000000     21.000000
#
# [8 rows x 54 columns]

# %% [markdown]
# Use count feature to determine whether there is any missing data (all should be same number)

# %%
df.count()
# Out:
# IL            10116
# cation        10116
# anion         10116
# x_CO2         10118
# T (K)         10118
# P (bar)       10117
# [CH3]         10117
# [CH2]         10117
# [CH]          10117
# [OCH2]        10117
# [OCH3]        10117
# [CF2]         10117
# [CF3]         10117
# [OH]          10117
# CH=CH         10117
# CH=CH2        10117
# [Im13]        10117
# [MIm]         10117
# [MMIM]        10117
# [Py]          10117
# [MPy]         10117
# [MPyrro]      10117
# [MPip]        10117
# [NH3]         10117
# [NH2]         10117
# [NH]          10117
# [N]           10117
# [P]           10117
# [S]           10117
# [BF4]         10117
# [Cl]          10117
# [DCA]         10117
# [NO3]         10117
# [PF6]         10117
# [SCN]         10117
# [TCB]         10117
# [C(CN)3]      10117
# [HSO4]        10117
# [FSA]         10117
# [Tf2N]        10117
# [BETA]        10117
# [FOR]         10117
# [TFA]         10117
# [C3F7CO2]     10117
# [MeSO4]       10117
# ...

# %%
import altair as alt
import datetime

# %%
temp= df['T (K)'].value_counts
temp
# Out:
# <bound method IndexOpsMixin.value_counts of 0         363.15
# 1         383.15
# 2         353.15
# 3         373.15
# 4         343.15
#           ...
# 10113     298.15
# 10114     343.15
# 10115     323.15
# 10116     243.20
# 10117    2982.00
# Name: T (K), Length: 10118, dtype: float64>

# %% [markdown]
# Sort the dataset in descending order of temperatures to determine what the highest temperatures are and if there are any outliers in terms of temperature.

# %%
df.sort_values('T (K)', ascending= False)[:20]
# Out:
#                  IL  cation   anion  ...  [DEPO4]  [DBPO4]  [methide]
# 10117           NaN     NaN     NaN  ...      NaN      NaN        NaN
# 1454    [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# 3575   [EMIM][Tf2N]  [EMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 1696   [BMIM][Tf2N]  [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 1717   [BMIM][Tf2N]  [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 3532   [EMIM][Tf2N]  [EMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 1752   [BMIM][Tf2N]  [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 3491   [EMIM][Tf2N]  [EMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 1786   [BMIM][Tf2N]  [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 3625   [EMIM][Tf2N]  [EMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 3626   [EMIM][Tf2N]  [EMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 3534   [EMIM][Tf2N]  [EMIM]  [Tf2N]  ...      0.0      0.0        0.0
# ...

# %%
df.sort_values('T (K)')[:200]
# Out:
#                  IL   cation   anion  ...  [DEPO4]  [DBPO4]  [methide]
# 7877    [OMIM][BF4]   [OMIM]   [BF4]  ...      0.0      0.0        0.0
# 7462    [HMIM][PF6]   [HMIM]   [PF6]  ...      0.0      0.0        0.0
# 7465    [HMIM][PF6]   [HMIM]   [PF6]  ...      0.0      0.0        0.0
# 7467    [HMIM][PF6]   [HMIM]   [PF6]  ...      0.0      0.0        0.0
# 7470    [HMIM][PF6]   [HMIM]   [PF6]  ...      0.0      0.0        0.0
# ...             ...      ...     ...  ...      ...      ...        ...
# 858     [BMIM][PF6]   [BMIM]   [PF6]  ...      0.0      0.0        0.0
# 1030   [BMIM][Tf2N]   [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 2978    [BMIM][PF6]   [BMIM]   [PF6]  ...      0.0      0.0        0.0
# 1052  [BMPYR][Tf2N]  [BMPYR]  [Tf2N]  ...      0.0      0.0        0.0
# 2976    [BMIM][PF6]   [BMIM]   [PF6]  ...      0.0      0.0        0.0
#
# [200 rows x 57 columns]

# %% [markdown]
# Sort the values for X_CO2 in descending order to make sure all values are between 0-1. Using this, we can determine any outliers.

# %%
df.sort_values('x_CO2', ascending=False)
# Out:
#                  IL  cation   anion  ...  [DEPO4]  [DBPO4]  [methide]
# 10117           NaN     NaN     NaN  ...      NaN      NaN        NaN
# 1402    [HMIM][BF4]  [HMIM]   [BF4]  ...      0.0      0.0        0.0
# 8510   [BMIM][TDfO]  [BMIM]  [TDfO]  ...      0.0      0.0        0.0
# 8508   [BMIM][TDfO]  [BMIM]  [TDfO]  ...      0.0      0.0        0.0
# 8505   [BMIM][TDfO]  [BMIM]  [TDfO]  ...      0.0      0.0        0.0
# ...             ...     ...     ...  ...      ...      ...        ...
# 787     [BMIM][BF4]  [BMIM]   [BF4]  ...      0.0      0.0        0.0
# 2089   [HMIM][Tf2N]  [HMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 1044   [BMIM][Tf2N]  [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 2151   [HMPY][Tf2N]  [HMPY]  [Tf2N]  ...      0.0      0.0        0.0
# 10116           NaN     NaN     NaN  ...     57.0     18.0       21.0
#
# [10118 rows x 57 columns]

# %% [markdown]
# Use the sum feature to determine if all group contributions are integers.

# %%
df.sort_values('IL').sum()
# Out:
# x_CO2         7.220856e+11
# T (K)         3.296348e+06
# P (bar)       5.488778e+05
# [CH3]         2.380400e+04
# [CH2]         9.557200e+04
# [CH]          4.320000e+02
# [OCH2]        3.940000e+02
# [OCH3]        8.520000e+02
# [CF2]         7.740000e+02
# [CF3]         2.020000e+02
# [OH]          1.160000e+03
# CH=CH         8.400000e+01
# CH=CH2        7.800000e+01
# [Im13]        2.142000e+02
# [MIm]         1.558800e+04
# [MMIM]        1.300000e+02
# [Py]          9.600000e+01
# [MPy]         2.280000e+02
# [MPyrro]      1.914000e+03
# [MPip]        7.200000e+01
# [NH3]         9.600000e+01
# [NH2]         1.560000e+02
# [NH]          7.000000e+01
# [N]           5.020000e+02
# [P]           1.086000e+03
# [S]           7.800000e+01
# [BF4]         2.232000e+03
# [Cl]          3.120000e+02
# [DCA]         4.400000e+02
# [NO3]         3.200000e+02
# [PF6]         2.232000e+03
# [SCN]         4.160000e+02
# [TCB]         1.240000e+02
# [C(CN)3]      1.510000e+03
# ...

# %% [markdown]
# Since Im13 has an error input (not a whole number), I sorted the values by Im13 in descending order to find the value in between 0-1 (not an integer).

# %%
df.sort_values('[Im13]', ascending=False) [:110]
# Out:
#                      IL      cation      anion  ...  [DEPO4]  [DBPO4]  [methide]
# 10116               NaN         NaN        NaN  ...     57.0     18.0       21.0
# 142    [(ETO)2IM][Tf2N]  [(ETO)2IM]     [Tf2N]  ...      0.0      0.0        0.0
# 144    [(ETO)2IM][Tf2N]  [(ETO)2IM]     [Tf2N]  ...      0.0      0.0        0.0
# 145    [(ETO)2IM][Tf2N]  [(ETO)2IM]     [Tf2N]  ...      0.0      0.0        0.0
# 146    [(ETO)2IM][Tf2N]  [(ETO)2IM]     [Tf2N]  ...      0.0      0.0        0.0
# ...                 ...         ...        ...  ...      ...      ...        ...
# 193       [BBIM][MeSO3]      [BBIM]    [MeSO3]  ...      0.0      0.0        0.0
# 116    [(ETO)2IM][Tf2N]  [(ETO)2IM]     [Tf2N]  ...      0.0      0.0        0.0
# 210       [BBIM][MeSO3]      [BBIM]    [MeSO3]  ...      0.0      0.0        0.0
# 197       [BBIM][MeSO3]      [BBIM]    [MeSO3]  ...      0.0      0.0        0.0
# 6881    [BMIM][C3F7CO2]      [BMIM]  [C3F7CO2]  ...      0.0      0.0        0.0
#
# ...

# %% [markdown]
# Sort pressure in descending order to make sure there are no outliers.

# %%
df.sort_values('P (bar)', ascending= False)
# Out:
#                       IL       cation   anion  ...  [DEPO4]  [DBPO4]  [methide]
# 10117                NaN          NaN     NaN  ...      NaN      NaN        NaN
# 1852        [BMIM][Tf2N]       [BMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 5030         [EMIM][PF6]       [EMIM]   [PF6]  ...      0.0      0.0        0.0
# 5884         [OMIM][BF4]       [OMIM]   [BF4]  ...      0.0      0.0        0.0
# 6137   [P6,6,6,14][Tf2N]  [P6,6,6,14]  [Tf2N]  ...      0.0      0.0        0.0
# ...                  ...          ...     ...  ...      ...      ...        ...
# 2090        [HMIM][Tf2N]       [HMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 2091        [HMIM][Tf2N]       [HMIM]  [Tf2N]  ...      0.0      0.0        0.0
# 2031    [C8F13MIM][Tf2N]   [C8F13MIM]  [Tf2N]  ...      0.0      0.0        0.0
# 10116                NaN          NaN     NaN  ...     57.0     18.0       21.0
# 1358         [BMIM][BF4]       [BMIM]   [BF4]  ...      0.0      0.0        0.0
#
# ...
